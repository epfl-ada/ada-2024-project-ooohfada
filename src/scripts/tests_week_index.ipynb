# %%
import pandas as pd
import numpy as np
import os

# copied from dataloader because of path issues in notebook
def load_raw_data(filename, n_first_rows):
    """
    Load the raw data from the file and return the first n_first_rows
    Parameters:
    filename (str): the name of the file to load
    n_first_rows (int): the number of rows to load
    Return:
    df (pd.DataFrame): the first n_first_rows of the file
    """
    
    df_timeseries = pd.read_csv(f'./../../data/{filename}', sep='\t', compression='infer', nrows=n_first_rows)
    df_timeseries['datetime'] = pd.to_datetime(df_timeseries['datetime'])

    return df_timeseries

# %%
# Load the time series data
df_timeseries = load_raw_data('df_timeseries_en.tsv', 18872500)

# Convert the datetime column to datetime format
df_timeseries['datetime'] = pd.to_datetime(df_timeseries['datetime'])

# %%
# Compute the week index from the first date in the dataset

# Get the first date in the dataset
first_date = df_timeseries['datetime'].min()
print(first_date)

# Get last date in the dataset
last_date = df_timeseries['datetime'].max()
print(last_date)

# Compute the week index
df_timeseries['week_index'] = df_timeseries['datetime'].apply(lambda x: (x - first_date).days // 7)
# Out:
# 2015-01-05 00:00:00
# 2019-09-30 01:00:00

# %%
df_timeseries.sort_values(by='datetime', inplace=True)
df_timeseries.reset_index(drop=True, inplace=True)
print(df_timeseries.head(50))
# Out:
#                      channel            category   datetime         views  \
# 0   UC1Ru5ZqoiF1cFwQSuFuv-KA              Gaming 2015-01-05  3.111235e+06
# 1   UCnYwVM9uyLGzTFfAkWqiUdQ              Gaming 2015-01-05  2.580014e+07
# 2   UCqzju-_WMKsgNx8R3QwupQQ       Howto & Style 2015-01-12  3.307442e+08
# 3   UC-IhaHBONjT0JjdOKqC21zQ  Film and Animation 2015-01-12  1.355811e+06
# 4   UCe8GMzGI_8fBfQYgOe3tBKA       Entertainment 2015-01-12  7.106681e+07
# 5   UCnYwVM9uyLGzTFfAkWqiUdQ              Gaming 2015-01-12  2.615005e+07
# 6   UC1Ru5ZqoiF1cFwQSuFuv-KA              Gaming 2015-01-12  3.135948e+06
# 7   UCjKOy4vngYbZMSXJbMmJoUQ              Gaming 2015-01-12  4.749135e+07
# 8   UCe8GMzGI_8fBfQYgOe3tBKA       Entertainment 2015-01-19  7.202908e+07
# 9   UCzqQPiNga359uISQxuKO1Fg       Howto & Style 2015-01-19  2.141333e+02
# 10  UC-IhaHBONjT0JjdOKqC21zQ  Film and Animation 2015-01-19  1.363066e+06
# 11  UC1Ru5ZqoiF1cFwQSuFuv-KA              Gaming 2015-01-19  3.139996e+06
# 12  UCqzju-_WMKsgNx8R3QwupQQ       Howto & Style 2015-01-19  3.310288e+08
# 13  UCnYwVM9uyLGzTFfAkWqiUdQ              Gaming 2015-01-19  2.649995e+07
# 14  UCjKOy4vngYbZMSXJbMmJoUQ              Gaming 2015-01-19  4.812762e+07
# 15  UCzqQPiNga359uISQxuKO1Fg       Howto & Style 2015-01-26  2.426000e+02
# 16  UCjKOy4vngYbZMSXJbMmJoUQ              Gaming 2015-01-26  4.984299e+07
# 17  UC-IhaHBONjT0JjdOKqC21zQ  Film and Animation 2015-01-26  1.370713e+06
# 18  UCe8GMzGI_8fBfQYgOe3tBKA       Entertainment 2015-01-26  7.299136e+07
# 19  UCqzju-_WMKsgNx8R3QwupQQ       Howto & Style 2015-01-26  3.306624e+08
# 20  UC1Ru5ZqoiF1cFwQSuFuv-KA              Gaming 2015-01-26  3.140600e+06
# 21  UCnYwVM9uyLGzTFfAkWqiUdQ              Gaming 2015-01-26  2.685136e+07
# 22  UCnYwVM9uyLGzTFfAkWqiUdQ              Gaming 2015-02-02  2.721185e+07
# 23  UCe8GMzGI_8fBfQYgOe3tBKA       Entertainment 2015-02-02  7.377032e+07
# 24  UC-IhaHBONjT0JjdOKqC21zQ  Film and Animation 2015-02-02  1.378292e+06
# 25  UCqzju-_WMKsgNx8R3QwupQQ       Howto & Style 2015-02-02  3.302960e+08
# 26  UCjKOy4vngYbZMSXJbMmJoUQ              Gaming 2015-02-02  5.153973e+07
# 27  UC1Ru5ZqoiF1cFwQSuFuv-KA              Gaming 2015-02-02  3.141203e+06
# 28  UCzqQPiNga359uISQxuKO1Fg       Howto & Style 2015-02-02  2.692000e+02
# 29  UCjKOy4vngYbZMSXJbMmJoUQ              Gaming 2015-02-09  5.403934e+07
# 30  UCe8GMzGI_8fBfQYgOe3tBKA       Entertainment 2015-02-09  7.441179e+07
# 31  UCzqQPiNga359uISQxuKO1Fg       Howto & Style 2015-02-09  2.846000e+02
# 32  UC-IhaHBONjT0JjdOKqC21zQ  Film and Animation 2015-02-09  1.385153e+06
# 33  UCnYwVM9uyLGzTFfAkWqiUdQ              Gaming 2015-02-09  2.757700e+07
# 34  UC1Ru5ZqoiF1cFwQSuFuv-KA              Gaming 2015-02-09  3.141806e+06
# 35  UCqzju-_WMKsgNx8R3QwupQQ       Howto & Style 2015-02-09  3.299296e+08
# 36  UCnxE3DNx_ZQcTY1ZGmCQ9kQ              Gaming 2015-02-16  8.957550e+04
# 37  UCnYwVM9uyLGzTFfAkWqiUdQ              Gaming 2015-02-16  2.791262e+07
# 38  UC-IhaHBONjT0JjdOKqC21zQ  Film and Animation 2015-02-16  1.395185e+06
# 39  UCqzju-_WMKsgNx8R3QwupQQ       Howto & Style 2015-02-16  3.295632e+08
# 40  UC1Ru5ZqoiF1cFwQSuFuv-KA              Gaming 2015-02-16  3.142410e+06
# 41  UCe8GMzGI_8fBfQYgOe3tBKA       Entertainment 2015-02-16  7.508618e+07
# 42  UCjKOy4vngYbZMSXJbMmJoUQ              Gaming 2015-02-16  5.448398e+07
# 43  UCzqQPiNga359uISQxuKO1Fg       Howto & Style 2015
# 2            1
# 3            1
# 4            1
# 5            1
# 6            1
# 7            1
# 8            2
# 9            2
# 10           2
# 11           2
# 12           2
# 13           2
# 14           2
# 15           3
# 16           3
# 17           3
# 18           3
# 19           3
# 20           3
# 21           3
# 22           4
# 23           4
# 24           4
# 25           4
# 26           4
# 27           4
# 28           4
# 29           5
# 30           5
# 31           5
# 32           5
# 33           5
# 34           5
# 35           5
# 36           6
# 37           6
# 38           6
# 39           6
# 40           6
# 41           6
# 42           6
# 43           6
# 44           7
# 45           7
# 46           7
# 47           7
# 48           7
# 49           7

# %%
df_timeseries.groupby('week_index')
print(df_timeseries[['datetime', 'week_index']].head(50))
# Out:
#      datetime  week_index
# 0  2015-01-05           0
# 1  2015-01-05           0
# 2  2015-01-12           1
# 3  2015-01-12           1
# 4  2015-01-12           1
# 5  2015-01-12           1
# 6  2015-01-12           1
# 7  2015-01-12           1
# 8  2015-01-19           2
# 9  2015-01-19           2
# 10 2015-01-19           2
# 11 2015-01-19           2
# 12 2015-01-19           2
# 13 2015-01-19           2
# 14 2015-01-19           2
# 15 2015-01-26           3
# 16 2015-01-26           3
# 17 2015-01-26           3
# 18 2015-01-26           3
# 19 2015-01-26           3
# 20 2015-01-26           3
# 21 2015-01-26           3
# 22 2015-02-02           4
# 23 2015-02-02           4
# 24 2015-02-02           4
# 25 2015-02-02           4
# 26 2015-02-02           4
# 27 2015-02-02           4
# 28 2015-02-02           4
# 29 2015-02-09           5
# 30 2015-02-09           5
# 31 2015-02-09           5
# 32 2015-02-09           5
# 33 2015-02-09           5
# 34 2015-02-09           5
# 35 2015-02-09           5
# 36 2015-02-16           6
# 37 2015-02-16           6
# 38 2015-02-16           6
# 39 2015-02-16           6
# 40 2015-02-16           6
# 41 2015-02-16           6
# 42 2015-02-16           6
# 43 2015-02-16           6
# 44 2015-02-23           7
# 45 2015-02-23           7
# 46 2015-02-23           7
# 47 2015-02-23           7
# 48 2015-02-23           7
# 49 2015-02-23           7

# %%
# Find and print rows with duplicate week indices
duplicate_weeks = df_timeseries[df_timeseries.duplicated(subset=['week_index'], keep=False)]

# Print the rows with 'datetime' and 'weekindex' columns
print(duplicate_weeks[['channel', 'datetime', 'week_index']].tail(50))

# TODO: Remove the duplicate rows from the dataset ? keep only 00:00:00 rows ?
# Out:
#                            channel            datetime  week_index
# 18872449  UC5J6SlEEnj28Zf1QbLNJ1ow 2019-09-30 01:00:00         247
# 18872450  UCQGswVycjt4v4zrvHyK6TCQ 2019-09-30 01:00:00         247
# 18872451  UCPnWeY_BurW8m3Q0q7v_g9Q 2019-09-30 01:00:00         247
# 18872452  UC2UJvNq5CbL2eEAReEDR_Bw 2019-09-30 01:00:00         247
# 18872453  UCBh2MtapL0Qbcby_v_hyEXA 2019-09-30 01:00:00         247
# 18872454  UC3plrhJApuJ_uapz_AMf7tw 2019-09-30 01:00:00         247
# 18872455  UCMUjCxhdYzl_yGhJp8yq4nw 2019-09-30 01:00:00         247
# 18872456  UCPKlmMK0Ybl8eSlctwKER1Q 2019-09-30 01:00:00         247
# 18872457  UCtlWNQjJr5vRGPiJZJBa4lw 2019-09-30 01:00:00         247
# 18872458  UCMxLVx3E2jU7RjjrUsiD93w 2019-09-30 01:00:00         247
# 18872459  UC3qiN2e6haEIuCTurf1xDDg 2019-09-30 01:00:00         247
# 18872460  UC0X9PT1B66UDpKsmGz83_Pw 2019-09-30 01:00:00         247
# 18872461  UCBPoTSAoYaRlgEXQZcc6Fiw 2019-09-30 01:00:00         247
# 18872462  UCr2SvXhFky8VSeykkEUa18g 2019-09-30 01:00:00         247
# 18872463  UClDERrRZzBA8KBTDmc4oZ2A 2019-09-30 01:00:00         247
# 18872464  UCbCQbUwKT2fBex0SzVg-h3Q 2019-09-30 01:00:00         247
# 18872465  UCn5tGXpe4fUl7ygyKrMYAfw 2019-09-30 01:00:00         247
# 18872466  UCj0Vi2KOhULmQ0YrcL17GKw 2019-09-30 01:00:00         247
# 18872467  UCK4i-Itm-RctKpjGESkMkwA 2019-09-30 01:00:00         247
# 18872468  UCFwphCi0VCIgB2Z_wxq5ntg 2019-09-30 01:00:00         247
# 18872469  UCtcuWUdbjleBUgmACsuY58w 2019-09-30 01:00:00         247
# 18872470  UCFNtxEtGass64CLdQkrksXg 2019-09-30 01:00:00         247
# 18872471  UCZa7FetevpPnf1FNvLU8BcQ 2019-09-30 01:00:00         247
# 18872472  UCxdAGtccDBjbaejXneQL-9Q 2019-09-30 01:00:00         247
# 18872473  UC31o0W-7jPD9rOzROZqLfTw 2019-09-30 01:00:00         247
# 18872474  UCzt3wUqBZsIUYeRDIaIMF8w 2019-09-30 01:00:00         247
# 18872475  UCpWRlcuKE2v2RK6-k0j9vhg 2019-09-30 01:00:00         247
# 18872476  UCNl-VAIGiBTgbb-PWY4MBDA 2019-09-30 01:00:00         247
# 18872477  UC3f6k-0vdkWZM9BQ916EOYQ 2019-09-30 01:00:00         247
# 18872478  UCdbr9Mbph36vplDKqEeNOHw 2019-09-30 01:00:00         247
# 18872479  UCDuNKwGyI11lO1_5us3XgyA 2019-09-30 01:00:00         247
# 18872480  UChnhuZzPqkJSrPP9XEIcSSA 2019-09-30 01:00:00         247
# 18872481  UCy-Db59r86eTPEfOZ5LoWnQ 2019-09-30 01:00:00         247
# 18872482  UC9tB_KFrcc5duY4Ks7QwOfw 2019-09-30 01:00:00         247
# 18872483  UCUT_DwIzVhA8A9RpjYNPblA 2019-09-30 01:00:00         247
# 18872484  UCjxWoDc8Hhb_TvDjvnbFGwg 2019-09-30 01:00:00         247
# 18872485  UCyyZ8gqlyWHLV3MjafDH67w 2019-09-30 01:00:00         247
# 18872486  UCXcRDz5ICBGq5LuCjufg1Qw 2019-09-30 01:00:00         247
# 18872487  UC9ff15w4ufviWfv9UfIuByA 2019-09-30 01:00:00         247
# 18872488  UCcwhqgP7x7KQdV2AEoQg7ZQ 2019-09-30 01:00:00         247
# 18872489  UC0rOiMiw4GfoTb-HvC8kgKQ 2019-09-30 01:00:00         247
# 18872490  UCJNTYYiDj4j5HuLRG6IkJaw 2019-09-30 01:00:00         247
# 18872491  UC9GPfUFP16933CjeQ2RYQVg 2019-09-30 01:00:00         247
# 18872492  UC7kQHyh3d6v6lAaR46J5XVQ 2019-09-30 01:00:00         247
# 18872493  UChqNkGCHm0-64x82qNIEwZA 2019-09-30 01:00:00         247
# 18872494  UCFHkOJlFU0uEeA0di7X7yLg 2019-09-30 01:00:00         247
# 18872495  UC_rqLZVSqhD4IKjzahdm6PQ 2019-09-30 01:00:00         247
# 18872496  UC0-swBG9Ne0Vh4OuoJ2bjbA 2019-09-30 01:00:00         247
# 18872497  UCvY_LjSx3Yttjz44lNxbGIA 2019-09-30 01:00:00         247
# 18872498  UCMuu2wpm1yJniHYAFRPCYHQ 2019-09-30 01:00:00         247

# %%
df_timeseries_grouped_by_channel = df_timeseries.groupby('channel')
print(df_timeseries_grouped_by_channel.get_group('UCXhkGgooXHDNwgJXmoTSN7g'))
# Out:
#                            channel category            datetime         views  \
# 23545     UCXhkGgooXHDNwgJXmoTSN7g    Music 2016-03-21 00:00:00  1.407062e+07
# 36754     UCXhkGgooXHDNwgJXmoTSN7g    Music 2016-03-28 01:00:00  1.412790e+07
# 42796     UCXhkGgooXHDNwgJXmoTSN7g    Music 2016-04-04 01:00:00  1.423378e+07
# 54336     UCXhkGgooXHDNwgJXmoTSN7g    Music 2016-04-11 01:00:00  1.430530e+07
# 75198     UCXhkGgooXHDNwgJXmoTSN7g    Music 2016-04-18 01:00:00  1.434464e+07
# ...                            ...      ...                 ...           ...
# 18248633  UCXhkGgooXHDNwgJXmoTSN7g    Music 2019-08-26 01:00:00  2.695777e+07
# 18357755  UCXhkGgooXHDNwgJXmoTSN7g    Music 2019-09-02 01:00:00  2.700862e+07
# 18515497  UCXhkGgooXHDNwgJXmoTSN7g    Music 2019-09-09 01:00:00  2.706119e+07
# 18642950  UCXhkGgooXHDNwgJXmoTSN7g    Music 2019-09-16 01:00:00  2.711444e+07
# 18755130  UCXhkGgooXHDNwgJXmoTSN7g    Music 2019-09-23 01:00:00  2.716740e+07
#
#             delta_views          subs  delta_subs  videos  delta_videos  \
# 23545      16179.750000   6443.250000    0.000000     832             0
# 36754      57276.575581   6480.037209   36.787209     832             0
# 42796     105880.356710   6508.156250   28.119041     832             0
# 54336      71514.625000   6534.406250   26.250000     832             0
# 75198      39347.281250   6571.229167   36.822917     832             0
# ...                 ...           ...         ...     ...           ...
# 18248633   50842.235294  14649.872549   47.764706     838             0
# 18357755   50842.235294  14697.637255   47.764706     838             0
# 18515497   52576.272059  14737.394608   39.757353     838             0
# 18642950   53249.823529  14774.041667   36.647059     838             0
# 18755130   52958.500000  14800.000000   25.958333     838             0
#
#           activity  week_index
# 23545            1          63
# 36754            1          64
# 42796            0          65
# 54336            0          66
# 75198            0          67
# ...            ...         ...
# 18248633         1         242
# 18357755         0         243
# 18515497         0         244
# 18642950         0         245
# 18755130         0         246
#
# [184 rows x 11 columns]

# %%
channel_id = 'UCWwWOFsW68TqXE-HZLC3WIA'
exists = channel_id in df_timeseries['channel'].values
print(exists)
# Out:
# True
