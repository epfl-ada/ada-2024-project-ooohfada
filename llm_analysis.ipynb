# %%
import pandas as pd
from tqdm import tqdm

from src.models.llm_call_helpers import *

# %% [markdown]
# # Load data
#
# Load the videos of interest = videos around declines for each channel. Each video comes with its channel, upload week, title and description.

# %%
videos = pd.read_csv('data/bb_videos_title_around_declines1.csv', index_col=(0))

videos
# Out:
#                         channel_id  week  \
# index
# 12471     UCzVw9odnihM5PgKSv5UnDPA   247
# 12472     UCzVw9odnihM5PgKSv5UnDPA   246
# 12473     UCzVw9odnihM5PgKSv5UnDPA   246
# 12474     UCzVw9odnihM5PgKSv5UnDPA   245
# 12475     UCzVw9odnihM5PgKSv5UnDPA   244
# ...                            ...   ...
# 72787994  UCs06q9pyRn8d8xy0NgzKPrA   216
# 72787995  UCs06q9pyRn8d8xy0NgzKPrA   216
# 72787996  UCs06q9pyRn8d8xy0NgzKPrA   215
# 72901188  UCrwmu-gceGOmtZeuTsn7DlQ   193
# 72901189  UCrwmu-gceGOmtZeuTsn7DlQ   175
#
#                                                       title
# index
# 12471     Most Funny Babies and Kids Playing in Water - ...
# 12472     Kids and Babies Trying to do Exercises   Funny...
# 12473     Cute and Adorable Moments of kids meeting newb...
# 12474       Cute Baby and His Daughter playing and Laughing
# 12475     Kids and Babies Meeting Animals in Village and...
# ...                                                     ...
# 72787994  Tay K Allegedly Started a new gang in Jail cal...
# 72787995  YNW Melly being investigated for a THIRD Murde...
# 72787996  Face To Face: Lil Reese x DJ Akademiks: Talks ...
# 72901188                     The Black Eyed Peas - BIG LOVE
# 72901189  The Black Eyed Peas - RING THE ALARM pt.1 pt.2...
#
# [107617 rows x 3 columns]

# %% [markdown]
# # Apply LLM functions
#
# For each video, apply the LLM functions to extract the following features:
# - whether the video is an apology video
# - whether the video addresses the decline
# - whether the video announces a comeback
# - whether the video announces a break
# - whether the video is a collaboration video
# - whether the video is a clickbait video

# %%
# apply the LLM model to the videos
tqdm.pandas()

videos['featuring'] = videos['title'].progress_apply(lambda x: featuring_another_creator(x))
# Out:
# 100%|██████████| 107617/107617 [8:55:53<00:00,  3.35it/s]

# %%
videos
# Out:
#                       channel_id  week  \
# 0       UCzVw9odnihM5PgKSv5UnDPA   247
# 1       UCzVw9odnihM5PgKSv5UnDPA   246
# 2       UCzVw9odnihM5PgKSv5UnDPA   246
# 3       UCzVw9odnihM5PgKSv5UnDPA   245
# 4       UCzVw9odnihM5PgKSv5UnDPA   244
# ...                          ...   ...
# 107612  UCs06q9pyRn8d8xy0NgzKPrA   216
# 107613  UCs06q9pyRn8d8xy0NgzKPrA   216
# 107614  UCs06q9pyRn8d8xy0NgzKPrA   215
# 107615  UCrwmu-gceGOmtZeuTsn7DlQ   193
# 107616  UCrwmu-gceGOmtZeuTsn7DlQ   175
#
#                                                     title featuring
# 0       Most Funny Babies and Kids Playing in Water - ...     False
# 1       Kids and Babies Trying to do Exercises   Funny...     False
# 2       Cute and Adorable Moments of kids meeting newb...     False
# 3         Cute Baby and His Daughter playing and Laughing     False
# 4       Kids and Babies Meeting Animals in Village and...     False
# ...                                                   ...       ...
# 107612  Tay K Allegedly Started a new gang in Jail cal...     False
# 107613  YNW Melly being investigated for a THIRD Murde...     False
# 107614  Face To Face: Lil Reese x DJ Akademiks: Talks ...      True
# 107615                     The Black Eyed Peas - BIG LOVE     False
# 107616  The Black Eyed Peas - RING THE ALARM pt.1 pt.2...     False
#
# [107617 rows x 4 columns]

# %%
videos['featuring'].value_counts()
# Out:
# featuring
# False    103463
# True       4150
# I             1
# I'm           1
# Not           1
# To            1
# Name: count, dtype: int64

# %%
# print the index of the videos that are apologies
apologies = videos[videos['featuring'] == 'True']
apologies
# Out:
#                       channel_id  week  \
# 132     UCzUV5283-l5c0oKRtyenj6Q   236
# 217     UCzT17-Lvc5L_gIT10JQsjSA   222
# 218     UCzT17-Lvc5L_gIT10JQsjSA   222
# 220     UCzT17-Lvc5L_gIT10JQsjSA   221
# 230     UCzT17-Lvc5L_gIT10JQsjSA   162
# ...                          ...   ...
# 107521  UCs11Yv5OnpY_b3Bff5ZJ9kw   191
# 107526  UCs11Yv5OnpY_b3Bff5ZJ9kw   188
# 107534  UCs11Yv5OnpY_b3Bff5ZJ9kw   178
# 107537  UCs11Yv5OnpY_b3Bff5ZJ9kw   173
# 107614  UCs06q9pyRn8d8xy0NgzKPrA   215
#
#                                                     title featuring
# 132                    Jim Acosta Meets Mark Dice (Again)      True
# 217     Buying YouTuber Merch and DIYing It With LaurD...      True
# 218            Doing Alisha Marie's Makeup for Coachella!      True
# 220                               Adelaine x Tarte Reveal      True
# 230           I Copied CloeCouture's Instagram for a Week      True
# ...                                                   ...       ...
# 107521       BOYFRIEND TAG! FT Jordan Beau | Jordyn Jones      True
# 107526    NEVER HAVE I EVER FT JORDAN BEAU | Jordyn Jones      True
# 107534     Jordyn Jones l New by Daya l BEHIND THE SCENES      True
# 107537  No Tears Left to Cry by Ariana Grande l Cover ...      True
# 107614  Face To Face: Lil Reese x DJ Akademiks: Talks ...      True
#
# [4150 rows x 4 columns]

# %%
# Basic stats on the featuring
print('Number of featuring:', len(apologies))
print('Number of videos:', len(videos))
print('Percentage of featuring:', len(apologies) / len(videos))
# Out:
# Number of featuring: 4150
# Number of videos: 107617
# Percentage of featuring: 0.03856268061737458

# %%
videos.to_csv('data/bb_videos_featuring.csv')
